# %%
#importing vital libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Customer Churn.csv') #loading the dataset

# %%
df.head() #first few rows of the dataset
# Out:
#    Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 0              8          0                    38               0
# 1              0          0                    39               0
# 2             10          0                    37               0
# 3             10          0                    38               0
# 4              3          0                    38               0
#
#    Seconds of Use  Frequency of use  Frequency of SMS  \
# 0            4370                71                 5
# 1             318                 5                 7
# 2            2453                60               359
# 3            4198                66                 1
# 4            2393                58                 2
#
#    Distinct Called Numbers  Age Group  Tariff Plan  Status  Age  \
# 0                       17          3            1       1   30
# 1                        4          2            1       2   25
# ...

# %%
df.tail()   # last few rows of the dataset
# Out:
#       Call  Failure  Complains  Subscription  Length  Charge  Amount  \
# 3145             21          0                    19               2
# 3146             17          0                    17               1
# 3147             13          0                    18               4
# 3148              7          0                    11               2
# 3149              8          1                    11               2
#
#       Seconds of Use  Frequency of use  Frequency of SMS  \
# 3145            6697               147                92
# 3146            9237               177                80
# 3147            3157                51                38
# 3148            4695                46               222
# 3149            1792                25                 7
#
#       Distinct Called Numbers  Age Group  Tariff Plan  Status  Age  \
# 3145                       44          2            2       1   25
# 3146                       42          5            1       1   55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Call  Failure            3150 non-null   int64
#  1   Complains                3150 non-null   int64
#  2   Subscription  Length     3150 non-null   int64
#  3   Charge  Amount           3150 non-null   int64
#  4   Seconds of Use           3150 non-null   int64
#  5   Frequency of use         3150 non-null   int64
#  6   Frequency of SMS         3150 non-null   int64
#  7   Distinct Called Numbers  3150 non-null   int64
#  8   Age Group                3150 non-null   int64
#  9   Tariff Plan              3150 non-null   int64
#  10  Status                   3150 non-null   int64
#  11  Age                      3150 non-null   int64
#  12  Customer Value           3150 non-null   float64
#  13  Churn                    3150 non-null   int64
# ...

# %%
df.isnull().sum()                    # checking if theres null values
# Out:
# Call  Failure              0
# Complains                  0
# Subscription  Length       0
# Charge  Amount             0
# Seconds of Use             0
# Frequency of use           0
# Frequency of SMS           0
# Distinct Called Numbers    0
# Age Group                  0
# Tariff Plan                0
# Status                     0
# Age                        0
# Customer Value             0
# Churn                      0
# dtype: int64

# %% [markdown]
# Exploratory analysis

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
df.describe()
# Out:
#        Call  Failure    Complains  Subscription  Length  Charge  Amount  \
# count    3150.000000  3150.000000           3150.000000     3150.000000
# mean        7.627937     0.076508             32.541905        0.942857
# std         7.263886     0.265851              8.573482        1.521072
# min         0.000000     0.000000              3.000000        0.000000
# 25%         1.000000     0.000000             30.000000        0.000000
# 50%         6.000000     0.000000             35.000000        0.000000
# 75%        12.000000     0.000000             38.000000        1.000000
# max        36.000000     1.000000             47.000000       10.000000
#
#        Seconds of Use  Frequency of use  Frequency of SMS  \
# count     3150.000000       3150.000000       3150.000000
# mean      4472.459683         69.460635         73.174921
# std       4197.908687         57.413308        112.237560
# min          0.000000          0.000000          0.000000
# ...

# %% [markdown]
# **VISUALISING THE CORRELATION**

# %%
#importing the vital libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlation = df.corr()
plt.figure(figsize=(10, 8)) # size of the figure
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# *By looking at the heatmap, you can quickly identify which variables are strongly correlated (either positively or negatively) and which ones are not.*

# %% [markdown]
# **BUILDING THE MODEL**

# %%
# importing vital libraries

from sklearn.model_selection import train_test_split # spliting the dataset into train and test
from sklearn.linear_model import LogisticRegression                     # model to be used
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %%
# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
 #Increase max_iter and use scaled data
logreg = LogisticRegression(max_iter=1000)  
logreg.fit(X_train_scaled, y_train)   # traing the dataset
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Model Evaluation using scaled data
y_pred_scaled = logreg.predict(X_test_scaled)

# Confusion Matrix
conf_matrix_scaled = confusion_matrix(y_test, y_pred_scaled)    # evaluate the performance of a classification algorithm
print("Confusion Matrix (scaled data):")
print(conf_matrix_scaled)

# Accuracy
accuracy_scaled = accuracy_score(y_test, y_pred_scaled) # see the accuracy
print("Accuracy (scaled data):", accuracy_scaled)

# Precision
precision_scaled = precision_score(y_test, y_pred_scaled)  # measure the accuracy of positive oucomes
print("Precision (scaled data):", precision_scaled)

# Recall
recall_scaled = recall_score(y_test, y_pred_scaled)  # measure the proportion of actual positive instances that were correctly identified by the model.
print("Recall (scaled data):", recall_scaled)

# F1 Score
f1_scaled = f1_score(y_test, y_pred_scaled)
print("F1 Score (scaled data):", f1_scaled)

# ROC Curve and AUC Score
y_prob_scaled = logreg.predict_proba(X_test_scaled)[:,1]
fpr_scaled, tpr_scaled, thresholds_scaled = roc_curve(y_test, y_prob_scaled)
roc_auc_scaled = auc(fpr_scaled, tpr_scaled)
print("ROC AUC Score (scaled data):", roc_auc_scaled)
# Out:
# Confusion Matrix (scaled data):
# [[504  16]
#  [ 66  44]]
# Accuracy (scaled data): 0.8698412698412699
# Precision (scaled data): 0.7333333333333333
# Recall (scaled data): 0.4
# F1 Score (scaled data): 0.5176470588235295
# ROC AUC Score (scaled data): 0.9046590909090909

# %% [markdown]
# **Model performance**

# %% [markdown]
# 1.
# The model correctly identifies a large proportion of true negatives, as reflected by the high number of true negatives (504) and high accuracy (87%).2.
# Precision is reasonably good at 73%, meaning when the model predicts positive, it is correct 73% of the time2. .
# The recall of 40% indicates a substantial number of actual positives are misse3. d.
# The F1 score of 52% highlights a balance between precision and recall but suggests room for improveme4. nt.
# The ROC AUC score of 90% demonstrates strong discriminative ability.
# To improve the model, particularly in terms of recall, strategies such as adjusting the classification threshold, using different algorithms, or focusing on handling class imbalance could be explored.
